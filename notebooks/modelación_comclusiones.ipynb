# %%
# %matplotlib inline
import pandas as pd

# %%
compras_df = pd.read_csv ('data/compras_df_enriched.csv')

# %% [markdown]
# # Probando un modelo supervisado

# %%
data = compras_df.copy()
for i, column in enumerate (list([str(d) for d in data.dtypes])):
    if column == 'object':
        data[data.columns[i]] = data[data.columns[i]].fillna (data[data.columns[i]].mode())
        data[data.columns[i]] = data[data.columns[i]].astype ("category").cat.codes
    else:
        data[data.columns[i]] = data[data.columns[i]].fillna (data[data.columns[i]].median())

# %%
data.head(8)
# Out:
#    NUM BEN  BENEFICIARIO  RFC  FACTURA  CONTRATO  CONCEPTO  TIPO         # OP  \
# 0   110152           161  167     1388       130       780     1    1019110.0
# 1   110152           161  167     1389       135       845     1    1019110.0
# 2   110152           161  167     1390       132       759     1    1019110.0
# 3   110152           161  167     1391       131       757     1    1019110.0
# 4   110152           161  167     1392       417       859     1  299001496.0
# 5   110152           161  167     1393       507       112     1  299001496.0
# 6   110152           161  167     1394       507       114     1  299001496.0
# 7   110152           161  167     1395       507       113     1  299001496.0
#
#    FECHA    IMPORTE  SHEET  DIA  MES   ANO  BENEFICIARIO_SALES  \
# 0      8   14911.80      2   11   12  2020                  13
# 1      8    2528.80      2   11   12  2020                  13
# 2      8    8500.02      2   11   12  2020                  13
# 3      8    2400.01      2   11   12  2020                  13
# 4     16    1537.00      2   23   12  2020                  13
# 5     16   79473.92      2   23   12  2020                  13
# 6     16  259837.68      2   23   12  2020                  13
# 7     16   60937.12      2   23   12  2020                  13
#
#    IMPORTE_GASTO_PROMEDIO  HAS_LINKEDIN_SITE
# 0           881659.731797               True
# 1           881659.731797               True
# 2           881659.731797               True
# 3           881659.731797               True
# 4           881659.731797               True
# 5           881659.731797               True
# 6           881659.731797               True
# 7           881659.731797               True

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
y = data.pop('IMPORTE')
X = data.copy()

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size = 0.33, random_state = 42)

# %%
clf = RandomForestRegressor(n_estimators=1000, max_depth =4)

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=1000)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, clf.predict(X_test))
# Out:
# 0.18670426459634748

# %% [markdown]
# ## Modelo no supervisado de clustering para texto

# %%
import gensim
import nltk.corpus 

import numpy as np
np.random.seed(2023)

# %%
pip install stopwords
# Out:
# Collecting stopwordsNote: you may need to restart the kernel to use updated packages.
#
#   Downloading stopwords-1.0.0-py2.py3-none-any.whl (37 kB)
# Installing collected packages: stopwords
# Successfully installed stopwords-1.0.0

# %%
import stopwords

# %%
def preprocess(text):
    result = []
    for token in text.split():
        if token not in stopwords('spanish') and len(token)>4:
            result.append(token)
    return result

# %%
process_business = [preprocess(x) for x in list(compras_df['BENEFICIARIO'].unique())]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 process_business = [preprocess(x) for x in list(compras_df['BENEFICIARIO'].unique())]
#
# Cell In[34], line 1, in <listcomp>(.0)
# ----> 1 process_business = [preprocess(x) for x in list(compras_df['BENEFICIARIO'].unique())]
#
# Cell In[33], line 4, in preprocess(text)
#       2 result = []
#       3 for token in text.split():
# ----> 4     if token not in stopwords('spanish') and len(token)>4:
#       5         result.append(token)
#       6 return result
#
# TypeError: 'module' object is not callable

# %% [markdown]
# # Probar un modelo no supervisado de anomalías en cuanto a importes

# %%
import numpy as np
from scipy.stats import norm

# %%
params = norm.fit(compras_df['IMPORTE'])

# %%
params
# Out:
# (626317.9473441559, 4665396.47441213)

# %%
compras_df['PROB_TOTAL'] = [norm(params[0], params[1]).cdf(x) for x in compras_df['IMPORTE']]

# 370  2020-12-28  3.610189e+07           GASTOS VARIOS   28   12  2020
# 372  2020-12-28  3.357936e+07           GASTOS VARIOS   28   12  2020
# 374  2020-12-28  1.336286e+07           GASTOS VARIOS   28   12  2020
# 586  2020-12-30  1.930300e+07           GASTOS VARIOS   30   12  2020
# 801  2020-12-08  1.134577e+07  CONTRATISTAS Y FDO FED    8   12  2020
# 851  2020-12-18  2.172712e+07  CONTRATISTAS Y FDO FED   18   12  2020
# 856  2020-12-11  1.951267e+07  CONTRATISTAS Y FDO FED   11   12  2020
# 858  2020-12-08  1.267303e+08  CONTRATISTAS Y FDO FED    8   12  2020
# 968  2020-12-28  9.612407e+06  CONTRATISTAS Y FDO FED   28   12  2020
#
#      BENEFICIARIO_SALES  IMPORTE_GASTO_PROMEDIO  HAS_LINKEDIN_SITE  PROB_TOTAL
# 283                   2           881659.731797               True    0.963661
# 353                   2           881659.731797               True    0.964862
# 354                   2           881659.731797               True    0.964978
# 357                   1           881659.731797              False    1.000000
# 367                  16           881659.731797               True    1.000000
# 368                  16           881659.731797               True    1.000000
# 369                  16           881659.731797               True    0.999967
# 370                  16           881659.731797               True    1.000000
# 372                  16           881659.731797               True    1.000000
# 374                  16           881659.731797               True    0.996833
# 586                   2           881659.731797               True    0.999969
# 801                   1           474566.765787               True    0.989209
# 851                  78           474566.765787               True    0.999997
# 856                   1           474566.765787               True    0.999974
# 858                   5           474566.765787               True    1.000000
# 968                   3           474566.765787               True    0.972955

# %%
models_sheet={}
for sheet in list(compras_df['SHEET'].unique()):
    sheet_compras = compras_df[compras_df['SHEET'] == sheet]
    params = norm.fit(sheet_compras['IMPORTE'])
    models_sheet[sheet] = norm(params[0], params[1])

# %%
sheet_prob = []
for i, row in compras_df.iterrows():
    sheet_prob.append(models_sheet[row['SHEET']].cdf(row['IMPORTE']))
compras_df['PROB_SHEET'] = sheet_prob

# %%
compras_df[compras_df['PROB_SHEET']>0.95]
# Out:
#       NUM BEN                                       BENEFICIARIO  \
# 283    116684                INDUSTRIAS SOLA BASIC, S.A. DE C.V.
# 353    126224                          BANCO MULTIVA, SA. G.F.M.
# 354    126224                          BANCO MULTIVA, SA. G.F.M.
# 357    126671       BANCO BANCREA,S.A. ,FIDEICOMISO NUMERO BP417
# 367    206894                MUNICIPIO DE LA CIUDAD DE MONTERREY
# 368    206894                MUNICIPIO DE LA CIUDAD DE MONTERREY
# 369    206894                MUNICIPIO DE LA CIUDAD DE MONTERREY
# 370    206894                MUNICIPIO DE LA CIUDAD DE MONTERREY
# 372    206894                MUNICIPIO DE LA CIUDAD DE MONTERREY
# 374    206894                MUNICIPIO DE LA CIUDAD DE MONTERREY
# 586    318568                 SERVICIOS BROXEL, S.A.P.I. DE C.V.
# 801    115716  SOLUCIONES Y OPCIONES DE SEGURIDAD PRIVADA,S.A...
# 851    115826                    CAR ONE MONTERREY, S.A. DE C.V.
# 856    116217                       RED RECOLECTOR, S.A. DE C.V.
# 858    116626  INTEGRACION DE SISTEMAS DE AVANZADA TECNOLOGIA...
# 968    123674          PROYECTOS Y DESARROLLOS SALVE, SA. DE CV.
# 1429   114466                          SISTEMEDIOS, S.A. DE C.V.
# 1430   114466                          SISTEMEDIOS, S.A. DE C.V.
# 1435   115189                       TV DE LOS MOCHIS,S.A.DE C.V.
# 1455   116439                          MULTIMEDIOS, S.A. DE C.V.
# 1456   116439                          MULTIMEDIOS, S.A. DE C.V.
# 1461   116563                       MILENIO DIARIO, S.A. DE C.V.
# 1499   203013                      CELEDONIO BECERRA JUAN MIGUEL
# 1506   203013                      HERNANDEZ SOTO BRENDA NATALIA
#
#                 RFC                  FACTURA      CONTRATO  \
# 283    ISB840628IB2     GS106845-158003-5868  SSP-189-2017
# 353    BMI061005NY5   FS-23-2020-158004-1712     NO APLICA
